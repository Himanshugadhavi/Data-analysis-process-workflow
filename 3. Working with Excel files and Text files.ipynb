# %% [markdown]
# # Excel files

# %%
import pandas as pd

# %%
pd.read_excel('data for analysis.xlsx')
# Out:
#       Unnamed: 0  Fodder yield at cut 1  Fodder yield at cut 2  \
# 0    Sole rye V1               131.0050               145.4525
# 1            NaN               122.7725               135.7625
# 2            NaN               123.2775               133.0525
# 3          V1+S2               136.1375               153.3025
# 4            NaN               141.6900               163.3175
# 5            NaN               144.3075               156.1000
# 6          V1+S3               126.8550               167.0250
# 7            NaN               131.3200               164.6800
# 8            NaN               132.9450               178.8025
# 9          V1+S4               121.2050               133.8225
# 10           NaN               125.7375               148.1075
# 11           NaN               119.7825               122.8900
# 12   Sole rye V2               125.3025               131.8375
# 13           NaN               129.7850               135.0100
# ...

# %%
pd.read_excel('data for analysis.xlsx',index_col='Unnamed: 0')
# Out:
#               Fodder yield at cut 1  Fodder yield at cut 2  \
# Sole rye V1                131.0050               145.4525
# NaN                        122.7725               135.7625
# NaN                        123.2775               133.0525
# V1+S2                      136.1375               153.3025
# NaN                        141.6900               163.3175
# NaN                        144.3075               156.1000
# V1+S3                      126.8550               167.0250
# NaN                        131.3200               164.6800
# NaN                        132.9450               178.8025
# V1+S4                      121.2050               133.8225
# NaN                        125.7375               148.1075
# NaN                        119.7825               122.8900
# Sole rye V2                125.3025               131.8375
# NaN                        129.7850               135.0100
# NaN                        125.2300               132.6800
# ...

# %%
'''when we are importing the excel format data then by default it will
import the first sheet of the excel file.
We can specify the sheet name in the read_excel function by using the 
sheet_name parameter'''

pd.read_excel('data for analysis.xlsx',sheet_name='Sheet2')

# we are importing the specific sheet of the excel file
# Out:
#     Total fodder yield  Dry matter yield  Crude protein yield  Gross returns  \
# 0             602.8000          128.7375            15.771483      127340.95
# 1             583.7325          124.7050            14.179869      126306.00
# 2             604.2200          129.4975            14.723777      132264.45
# 3             589.0000          116.1100            16.255934      122591.00
# 4             620.1925          122.1900            16.032044      127720.44
# 5             627.9950          123.7850            16.241553      124241.10
# 6             555.3600          106.3000            16.742975      126053.95
# 7             584.4325          111.9100            16.081224      127609.90
# 8             575.6875          110.2950            17.372475      125574.05
# 9             481.4025           90.3325            16.594153      111670.55
# 10            532.3225           99.9625            17.492939      119207.00
# ...

# %% [markdown]
# # Text files

# %%
# it is imported through pd.read_csv() function 
# in that we will be using the sep parameter as per requirement
